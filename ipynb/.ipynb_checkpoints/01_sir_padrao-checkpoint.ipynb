# %% [markdown]
# # Introdução
# O presente estudo, desenvolvido por Pedro Eduardo Souza Abreu e Pedro Vítor de Abreu, se propõe a entender a propagação da epídemia de  **Covid-19** no Brasil ou em suas regiões. Entender o problema é requisito inicial para analisar soluções de como sair da crise sanitária e econômica. Para tanto, caminharemos por etapas e em cada uma delas discorreremos sobre os métodos matemáticos utilizados e suas intercorrências.
# Nesta primeira vamos entender o método **SIR** padrão. A cada página colocamos um código em python autoexecutável para expor o assunto tratado e gerar as respectivas experimentações.
# Futuramente pretendemos abordar a problemática da previsibilidade epidemiológica adicionando ao modelo **SIR** padrão os fatores seguintes:
# 1. A Existência de Clusters populacionais semi-independentes.
# 2. Variação das taxas de propagação por consequências geo-demográficas.
# 3. O efeito de medidas de conteção e isolamento social.
# 4. O efeito de medidas de autopresrvação individual frente o aumento da mortalidade.
# 3. O efeito do estresse do sistema de saúde sobre a mortalidade e, em especial, o crítico efeito de se exceder a capacidade de respiradores nas UTIs do sistema.
# 4. O efeito da introdução de novas técnicas e novos medicamentos.
#
# Como o modelo **SIR** considera como hipótese básica uma população homogênea, chamaremos de um cluster populacional um conjunto da população contígua e que se comporta de forma homogênea.
# ## O Modelo SIR Padrão
# Um dos modelos matemáticos, muito utilizado, que descreve a propagação de uma doença em uma população entre compartimentos é o modelo SIR padrão que considera um número de população fixa sendo transportadas entre três compartimentos conforme funções do tempo 't'. Na oredem cronológica são eles:
# * S(t) são todos os indivíduos suscetíveis ainda não infectados
# * I(t) é o número de indivíduos infectados.
# * R(t) são todos os indivíduos recuperados e, agora, imunizados.
#
# ### Taxa de transmissão
# Entre **S** e **I** a taxa de transmissão é &beta;\*I, onde &beta; é a média do número de contatos por dia multiplicado pela probabilidade da transmissão da infecção pelo contato entre um indivíduo suscetível e um infectado.
# Entre **I** e **R** a taxa de transmissão &gamma; é simplismente a taxa de recuperação ou de mortalidade durante um dia pelo total de infectados neste mesmo dia. Se a duração da infecciosidade de um indivíduo for denotado por **D** , então &gamma; = 1/D.
#
#
#
# O fluxo cronológico é o seguinte::
#
#
#
# $${\Large S \xrightarrow{\frac{\beta SI}{N} } I \xrightarrow{\gamma I} R}$$
#
#
#     E as equações diferenciais que descrevem o modelo são:
#
#
# $${\displaystyle \frac{dS}{dt} = - \frac{\beta SI}{N}}$$
#
# $${\displaystyle \frac{dI}{dt} = \frac{\beta SI}{N} - \gamma I}$$
#
# $${\displaystyle \frac{dR}{dt} = \gamma I}$$
#
# O sistema, embora não linear, pode ser resolvido analitica ou numericamente pois podemos afirmar que d**S**/dt + d**I**/dt + d**R**/dt = 0, o que resulta que: **S**(t) + **I**(t) + **R**(t) = **N**, o que expressa matematicamente a constância da população **N** e implica que precisamos de apenas duas das três variáveis para solucionar nosso sistema.
#
# Para traçar a curva de infecções por dia basta discretizar o resultado da integração do termo $${\displaystyle i\_dia = \frac{\beta}{N}SI}$$
#
#
#
# Podemos observar que a dinâmica da epidemia depende da seguinte razão:
#
# $${\displaystyle \Re\circ_ = \frac{\beta}{\gamma} }$$
#
# ${\Re\circ}$ é chamado de número de reprodução básica ou razão de reprodução e indica o número de pessoas que serão infectadas por uma única, se $\Re\circ$ > 1 haverá expansão da epidemia.
#
#
#
#
#
# ## Exemplos
# Vamos simular a propagação da epidemia por seis meses em uma cidade de um milhão de habitantes variando as taxas de propagação entre os compartimentos S->I->R, iniciando com um único indivíduo infectado em 01 de maço de 2020.
# ### Exemplo 1
# Os dados nos mostram que na fase inicial da epidemia de Covid-19 o valor da taxa de transmissão &beta; chega em alguns paises no valor máximo de 1, como 1/&gamma;, que representa o número de dias que um indivíduo infecta outro é de 5 dias. (15 dias de infecção sendo 10 deles sintomáticos onde se presume que isolado o indivíduo não infecte os demais.) Com &beta; = 1 e &gamma; = 1/5 obtemos um ${\Re\circ}$ = 5
# ![exemplo_1](../img/01_sir/01_sir_padrao_cluster_unico_exemplo_01.png)
# ### Exemplo 2
# Felizmente, em todos os paises,  o ${\Re\circ}$ cai rapidamente durante a epidemia devido a fatores comportaentais, agora o mesmo exemplo com ${\Re\circ}$ = 2.5
# ![exemplo_2](../img/01_sir/01_sir_padrao_cluster_unico_exemplo_02.png)
# ### Exemplo 3
# E com adequado distânciamento social por isolamento ${\Re\circ}$ pode transitar em torno de 1
# ![exemplo_3](../img/01_sir/01_sir_padrao_cluster_unico_exemplo_03.png)
# ### Exemplo 4
# Adotando agora um ${\Re\circ}$ = 2.5 (igual ao exemplo 2) vamos variar o período infeccioso neste exemplo para 1/&gamma; = 3
# dias
# ![exemplo_4](../img/01_sir/01_sir_padrao_cluster_unico_exemplo_04.png)
# ### Exemplo 2 (novamente)
# Repetindo o exemplo 2 ${\Re\circ}$ = 2.5 e 1/&gamma; = 5
# ![exemplo_2](../img/01_sir/01_sir_padrao_cluster_unico_exemplo_02.png)
# ### Exemplo 5
# Adotando agora  1/&gamma; = 7 dias
# ![exemplo_4](../img/01_sir/01_sir_padrao_cluster_unico_exemplo_05.png)
# ### Exemplo 6
#
# ### Conclusão SIR Padrão
# xxxxxxxxxxxxxxx  ESCREVER
# ## Bibliografia
# 1. Compartmental models in epidemiology - Wikipedia
#
# ## Código
# A seguir, o código em python para analisarmos várias hipóteses e traçar diretrizes a um trabalho com maior profundidade.
# ### Dados de entrada:
# Além dos parâmetros necessários como as condições iniciais para a integração das equações diferenciais vamos utilizar os seguintes:
#
# Parâmetro | Descrição | Observações
# --|--|--
# pop | População do cluster | Fixa, desconsidernado o fator vital
# i_ini | População infectada inicial |
# s_ini | Susctíveis iniciais |
# r_ini | Recuperados iniciais |
# r_zero | Taxa de propagação | Número de infectados por um único indivíduo infectado
# gama_inv | Período infectante | Em que o indivíduo pode transmitir a infecção
# gama | Fator de recuperação | 1 / dias_infec
# beta | Fator de propagação | beta = r_zero * gama
# data_ini | Data inicial da epidemia no cluster | ano-mês-dia
# tot_dias | Total de dias da análise | A partir de data_ini
#
#
# **Next in this page:**
# 1. Refatorar (código)
# 2. Escrever explicando melhor a teoria e o modelo. (markdown)
# 3. Escrever a conclusão (markdown)
# 4. Exemplo 6 com R0 < 1 (markdown)
#
#
# **Next in the other pages:**
# 1. SIRD acrescido de Hospitalização, UTI e Mortes
# 2. Inserir vetor para variação de beta e, talvez, gama.
# 3. Modelar para vários clusters com repetitividade e interconexão entre eles.
# 4. Modelar mortes também em função de estresse do sistema de saúde, em especial, ao exceder respiradores.
# 5. Modelar o efeito de medicamentos que alterem o tratamento, por exemplo, redução do tempo de UTI, etc.
# 6. Modelar com cluster por idade e grupo de risco
# 7. Pedu, sugira qualquer coisa em qualquer parte....

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue May  5 17:40:00 2020

@author: 
pedro eduardo souza abreu pedu.abreu@gmail.com
pedro vitor abreu  eng.pva@gmail.com
"""
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

def run(
        pop: 'população',
        i_ini: 'infectados iniciais',
        r_ini: 'recuperados iniciais',
        r_zero: 'razão de reprodução',
        gama_inv: 'período de recuperação',
        t_max: 'tempo total analisado',
        data_ini: 'data inicial') -> pd.DataFrame:    
    s_ini = pop - i_ini - r_ini
    gama = 1/gama_inv if gama_inv != 0 else 1.
    beta = gama * r_zero 
    t_list = np.arange(t_max)
    seq_dias = np.arange(data_ini, data_ini + t_max, dtype= 'datetime64[D]')
    res_integr = integrar(s_ini, i_ini, r_ini, beta, gama, t_max)
    s,i,r,i_acum = res_integr
    return pd.DataFrame({'S': s, 'I': i, 'R': r, 'I_acum':i_acum,
                         'D': seq_dias}, index=t_list)

def integrar(
    si: 'suscetíveis iniciais',
    ii: 'infectados iniciais',
    ri: 'resolvendo inicias',
    b: 'taxa de propagação S->I',
    g: 'taxa de recuperação I->R',
    t_max: 'número de dias analisados'
    ): # retorna (s,i,r,i_acum) np.array
    s = np.zeros(t_max, dtype = float)
    i = s.copy(); r = s.copy(); i_acum = s.copy()   
    s[0] = si
    i_acum[0] = ii
    i[0] = ii
    r[0] = 1
    n = si + ii + ri
    for t in np.arange(t_max - 1, dtype = int):
        s[t+1]      = s[t] - (b * s[t] * i[t] / n)
        i[t+1]      = i[t] + (b * s[t] * i[t] / n) - (g * i[t])
        r[t+1]      = r[t] + g * i[t]
        i_acum[t+1] = i_acum[t] + (b * s[t] * i[t] / n)
    return (s,i,r,i_acum)   

def plotar(
        tit: 'Título da figura de plotagem, incui parâmetros principai',
        res: 'DataFrame com resultados',
        data_plt_ini: 'ano-mes-dia inicio da plotagem',
        data_plt_fim: 'ano-mes-dia fim da plotagem'):
    
    fig = plt.figure(edgecolor='b', facecolor='whitesmoke', figsize=(15,7.5))
    ax1 = fig.add_subplot(111)    
    showdate_ini = np.datetime64(data_plt_ini)
    showdate_end = np.datetime64(data_plt_fim)    
    ax1.plot(res['D'], res['I_acum'], 'r',lw=2, label="Infectados Acumuladas")    
    ax1.plot(res['D'], res['I'] , 'r--', lw=2, label="Infectados")
    ax1.plot(res['D'], res['S'], 'b', lw=2, label="Suscetíveis")
    ax1.plot(res['D'], res['R'], 'g', lw=2, label="Recuperados")    
    ax1.set_ylabel('População')
    ax1.set_xlim(showdate_ini,showdate_end)    
    ax1.set_xticks(np.arange(showdate_ini,showdate_end , 7, dtype='datetime64[D]'))
    ax1.set_yticks(np.arange(0, pop, pop/20))
    ax1.xaxis.set_tick_params(rotation=90) 
    ax1.grid(b = True, which = 'major', c = 'silver', lw=1, ls='-') 
    ax1.set_title(tit, fontsize=12, pad =25)        
    legend_1 = ax1.legend(loc= 'center left')
    legend_1.get_frame().set_alpha(0.5)

if __name__ == '__main__':
    pop = 1_000_000
    i_ini,r_ini = 1., 0
    r_zero, gama_inv = 3.,5   
    t_max = 180
    data_ini = np.datetime64('2020-03-01')    
    res = run(pop, i_ini, r_ini, r_zero, gama_inv, t_max, data_ini)    
    tit = 'Fig_1: SIR Padrão Cluster Único. População: {:,} Infect.Ini: {}\
    R0: {} Gama_inv: {}'.format(pop, i_ini, r_zero, gama_inv)    
    plotar(tit,res,'2020-03-01','2020-08-30')
